# %%
import numpy as np

from modspectra.cube import EmissionCube
import astropy.units as u
from astropy.coordinates import SkyCoord

import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns
from matplotlib.colors import LogNorm
pal = sns.color_palette('colorblind', 10)

sns.set(color_codes=True)
sns.axes_style("white")
sns.set_style('whitegrid')

import copy
from scipy.io.idl import readsav
import matplotlib.gridspec as gridspec

from whampy import SkySurvey

# %%
spectra_filename = "/Users/dk/Dropbox/UW/Astro/Research/tilted_ring/Model/model_cubes/Elliptical/dk_nss_sss.sav"

# %%
spectra_filename = "/Users/dk/Dropbox/UW/Astro/Research/tilted_ring/Model/model_cubes/Elliptical/reduced_data_R.sav"

# %%
ha_idldata = readsav(spectra_filename)

# %%
ha_idldata.keys()
# Out:
# dict_keys(['ha', 'hb', 'sii', 'nii', 'oiii'])

# %%
ha_idldata["ha"]["GLON"].shape
# Out:
# (81,)

# %%
ha = SkySurvey(filename = spectra_filename, idl_var = "ha")
hb = SkySurvey(filename = spectra_filename, idl_var = "hb")
nii = SkySurvey(filename = spectra_filename, idl_var = "nii")
sii = SkySurvey(filename = spectra_filename, idl_var = "sii")
oiii = SkySurvey(filename = spectra_filename, idl_var = "oiii")
# Out:
# /anaconda3/envs/mw/lib/python3.7/site-packages/astropy/table/column.py:981: RuntimeWarning: invalid value encountered in less
#   return getattr(self.data, op)(other)

# %%
nii_neg = nii.moment(vmin = -110, vmax= -50)
ha_neg = ha.moment(vmin = -110, vmax= -50)
# Out:
# WARNING:root:No units specified for vmin, assuming u.km/u.s
# WARNING:root:No units specified for vmax, assuming u.km/u.s
# /anaconda3/envs/mw/lib/python3.7/site-packages/astropy/table/column.py:981: RuntimeWarning: invalid value encountered in less
#   return getattr(self.data, op)(other)
# WARNING:root:No units specified for vmin, assuming u.km/u.s
# /anaconda3/envs/mw/lib/python3.7/site-packages/astropy/table/column.py:981: RuntimeWarning: invalid value encountered in less_equal
#   return getattr(self.data, op)(other)
# WARNING:root:No units specified for vmax, assuming u.km/u.s
# /anaconda3/envs/mw/lib/python3.7/site-packages/astropy/table/column.py:981: RuntimeWarning: invalid value encountered in greater_equal
#   return getattr(self.data, op)(other)

# %%
c = ha.click_map(c = ha_neg.value, over_data=sii, share_yaxis = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ha.click_map?

# %%
ha = SkySurvey(filename = spectra_filename, idl_var="sub_sss_post")
ha["DATA"] /= 22.8
ha["VARIANCE"] /= 22.8**2

# %%
fig = ha.click_map(colorbar = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
neg_ha = ha.moment(vmin=-110, vmax = -50)
# Out:
# WARNING:root:No units specified for vmin, assuming u.km/u.s
# WARNING:root:No units specified for vmax, assuming u.km/u.s

# %%
fig = ha.click_map(colorbar = True, c = neg_ha.value, 
                   vmin = .01, vmax = 10, 
                   over_data="gc_hi.fits")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ha.click_map?
